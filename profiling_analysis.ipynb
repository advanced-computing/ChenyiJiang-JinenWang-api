# %%
import pandas as pd

from data_clean import load_and_clean_data

df = load_and_clean_data("data.csv")

df
# Out:
#         id                name gender  pictured  \
# 0   350525              Jovita      F         1
# 1   138072                Mary      F         1
# 2   521248             Merlita      F         1
# 3   199163               Kioko      M         1
# 4   541831            Magnolia      F         1
# ..     ...                 ...    ...       ...
# 95  651489  Las Perlitas Group      F         1
# 96  390188             Martina      F         1
# 97    6227            Georgina      F         1
# 98  618688  Mirian Del Socorro      F         1
# 99  381457               Grace      F         1
#
#                                           description  loan_amount  \
# 0   Jovita continues participating with Asociación...          575
# 1   Mary is 42 years old and married with 4 childr...          525
# 2   Merlita is 39 years old, married, and blessed ...          125
# 3   Kioko is a 50-year-old man who is married with...          275
# ...

# %% [markdown]
# # Takeaways of Five Findings:
#
# Gender Distribution: The vast majority of borrowers are female (F), with a very small percentage being male (M).
#
# Missing Values: The languages ​​column has a large number of missing values, which need to be handled during analysis.
#
# Loan Amount: The median loan amount is around 500, with a few outliers of extremely high amounts.
#
# Sectors: 'Agriculture' and 'Food' are the most common sector categories.
#
# Repayment Term: The repayment term for most loans is between 8 and 14 months.
