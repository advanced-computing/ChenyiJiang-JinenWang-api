# %%
import pandas as pd

from data_clean import load_and_clean_data

df = load_and_clean_data("data.csv")

df
# Out:
#         id                name gender  pictured  \
# 0   350525              Jovita      F         1
# 1   138072                Mary      F         1
# 2   521248             Merlita      F         1
# 3   199163               Kioko      M         1
# 4   541831            Magnolia      F         1
# ..     ...                 ...    ...       ...
# 95  651489  Las Perlitas Group      F         1
# 96  390188             Martina      F         1
# 97    6227            Georgina      F         1
# 98  618688  Mirian Del Socorro      F         1
# 99  381457               Grace      F         1
#
#                                           description  loan_amount  \
# 0   Jovita continues participating with Asociación...          575
# 1   Mary is 42 years old and married with 4 childr...          525
# 2   Merlita is 39 years old, married, and blessed ...          125
# 3   Kioko is a 50-year-old man who is married with...          275
# ...

# %%
print("Shape of dataset:", df.shape)

print("\nData types:")
print(df.dtypes)
# Out:
# Shape of dataset: (100, 14)
#
# Columns:
# Index(['id', 'name', 'gender', 'pictured', 'description', 'loan_amount',
#        'activity', 'sector', 'country', 'town', 'posted_date',
#        'repayment_term', 'languages', 'days_until_funded'],
#       dtype='object')
#
# Data types:
# id                                 int64
# name                              object
# gender                            object
# pictured                           int64
# description                       object
# loan_amount                        int64
# activity                          object
# sector                            object
# country                           object
# town                              object
# posted_date          datetime64[ns, UTC]
# repayment_term                     int64
# languages                         object
# days_until_funded                  int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#                    id  name gender  pictured  \
# count      100.000000   100    100    100.00
# unique            NaN    95      2       NaN
# top               NaN  Mary      F       NaN
# freq              NaN     2     80       NaN
# mean    309262.410000   NaN    NaN      0.99
# min       4056.000000   NaN    NaN      0.00
# 25%     142356.500000   NaN    NaN      1.00
# 50%     302615.500000   NaN    NaN      1.00
# 75%     456613.000000   NaN    NaN      1.00
# max     673800.000000   NaN    NaN      1.00
# std     187760.017709   NaN    NaN      0.10
#
#                                               description  loan_amount  \
# count                                                 100   100.000000
# unique                                                100          NaN
# top     Jovita continues participating with Asociación...          NaN
# freq                                                    1          NaN
# ...

# %% [markdown]
# # Takeaways of Five Findings:
#
# 1. Gender Distribution: Gender highly skewed toward female. Female (F) = 80% / Male (M) = 20%
#
# 2. Loan Amount: Loan amount distribution is right-skewed. The average value is significantly higher than the median, indicating that there is a large amount of high-value loans that have pushed up the average.
#
# 3. Repayment Term: The repayment term for most loans is between 8 and 14 months. Repayment term shows wide dispersion.
#
# 4. Sectors / Activities: 'Agriculture' and 'Food' are the most common sector categories.
#
# 5. Missing Values: The languages ​​column has a large number of missing values, which need to be handled during analysis.
